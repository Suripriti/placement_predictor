# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:\\Users\\prem2\\Downloads\\placement.csv")
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df["placed"].unique()
# Out:
# array([1, 0])

# %%
x=df[["cgpa","placement_exam_marks"]]
y=df["placed"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
print("----x_train-----")
print(x_train)
print("----y_train-----")
print(y_train)
# Out:
# ----x_train-----
#      cgpa  placement_exam_marks
# 601  6.89                  17.0
# 563  6.81                  14.0
# 341  7.41                   8.0
# 671  7.45                  31.0
# 138  7.53                   8.0
# ..    ...                   ...
# 840  6.89                  22.0
# 30   7.46                  16.0
# 705  6.55                  35.0
# 301  7.84                   5.0
# 337  6.95                  68.0
#
# [800 rows x 2 columns]
# ----y_train-----
# 601    1
# 563    1
# 341    1
# 671    0
# 138    1
#       ..
# 840    1
# 30     0
# 705    1
# 301    1
# 337    0
# Name: placed, Length: 800, dtype: int64

# %%
print("----x_test-----")
print(x_test)
print("----y_test-----")
print(y_test)
# Out:
# ----x_test-----
#      cgpa  placement_exam_marks
# 553  7.46                  17.0
# 985  7.10                  26.0
# 945  6.71                  26.0
# 973  6.10                  37.0
# 964  8.09                  54.0
# ..    ...                   ...
# 42   7.46                  71.0
# 948  6.38                  15.0
# 426  7.26                  21.0
# 312  7.02                  55.0
# 741  7.58                  66.0
#
# [200 rows x 2 columns]
# ----y_test-----
# 553    0
# 985    0
# 945    1
# 973    1
# 964    1
#       ..
# 42     1
# 948    0
# 426    0
# 312    1
# 741    0
# Name: placed, Length: 200, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train, y_train)

model.predict([[7.19,26.0]])
# Out:
# c:\Users\prem2\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.49607288])
